# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermefritz/SQL_Projects/blob/main/Transforma%C3%A7oes_dados_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Feito por Guilherme Fritz

# %% [markdown]
# **Esse projeto tem o objetivo de demonstrar as transformações que são aplicadas nas variaveis  para a realização de análises,construção de gráficos e modelagem preditiva**
#    * Categorização
#    * Enconding (Label Encoding e One -Hot enconding)
#    * Binarização

# %%
#upload de imagens no colab
from google.colab import files
uploaded = files.upload()

import cv2
from google.colab.patches import cv2_imshow
# Out:
#      <input type="file" id="files-70636045-ae42-457d-b381-3c8fc79b0949" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70636045-ae42-457d-b381-3c8fc79b0949">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Banco de dados -Avaliação de carros.
#
# disponivel em https://archive.ics.uci.edu/dataset/19/car+evaluation

# %% [markdown]
# ### Assim estava o banco de dados antes das transformações:

# %%
imagem = cv2.imread('/content/BD2.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x582>

# %% [markdown]
# # **OBS:**

# %% [markdown]
# ### Necessário antes de cada transformaçao a verificação de valores ausentes em cada variavel,pode-se fazer isso utilizando o DISTINCT
# Não utilizei no projeto para que nao ficasse com excesso de imagens

# %% [markdown]
# # Categorização

# %% [markdown]
# * O objetivo da categorização seria para diminuir a dimensionalidade da variavel categorica e facilitar analises

# %% [markdown]
# Verifiquei que a variavel 'buying' era composta por 4 classes :['vhigh' 'high' 'med' 'low'] e transformamos em 2 classes :['Alto' ,'Baixo']

# %%
imagem = cv2.imread('/content/c.buying.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x730>

# %% [markdown]
# # Enconding

# %% [markdown]
# * O objetivo do enconding seria transformar a variavel categorica para sua representação númerica

# %% [markdown]
# ##  *Label Encoding

# %% [markdown]
# -Verifiquei que a variavel categorica 'safety' era composta por 3 classes :['low' 'med' 'high'],apliquei o enconding para obter a representação numerica da variavel que ficou assim [1,2,3]

# %%
imagem = cv2.imread('/content/Enc_safety.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# -Verifiquei que a variavel 'Target' estava categorica  e que  era composta por 4 classes :['unacc' 'acc' 'vgood','good'],apliquei o enconding para obter a representação numerica da variavel que ficou assim [1,2,3,4]

# %%
imagem = cv2.imread('/content/Enc_target.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# ## * One-hot-enconding

# %% [markdown]
#  **One-hot-enconding**-Tecnica utilizada para transformar as variaveis categoricas em variaveis dummy

# %% [markdown]
# -Verifiquei que a variavel 'lug_bot' estava categorica e que era composta por 3 classes :['small','med','big'] e representação numerica da variavel que ficou distribuida em tres colunas.

# %%
imagem = cv2.imread('/content/one_hot.lug.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# # Banco de dados após as transformações:

# %%
imagem = cv2.imread('/content/BD FINAL 2.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x698>

# %% [markdown]
# **Com as variaveis 'buying',lug_bot,safety,Target modificadas**

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Binarização

# %% [markdown]
# * A binarização é usada para converter a variável categórica em uma representação numérica[0,1],em que normalmente a classe negativa recebe '0' e a classe positiva '1'

# %% [markdown]
# **Banco de dados -Dados de paciente com cãncer de mama**

# %% [markdown]
#  **Nesse exemplo utilizo um banco de dados disponivel em https://archive.ics.uci.edu/dataset/14/breast+cancer**

# %% [markdown]
# **O banco de dados estava assim inicialmente**

# %%
imagem = cv2.imread('/content/BD.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# -Verifiquei que a variavel 'irradiando' era composta pelas classe ['yes','no'] e binarizei[0,1]

# %%
imagem = cv2.imread('/content/b.irradiando.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# Verifiquei que a variavel 'classe' era composta pelas classe ['no-recurrence-eventss','recurrence-events'] e binarizei -[0,1]

# %%
imagem = cv2.imread('/content/b.classe.png')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768>

# %% [markdown]
# # FIM
